# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#red_df = pd.read_csv('C:/Users/Eugene/Documents/GitHub/BoyWithLuv-Team/Wine_Quality/wine_data/winequality-red.csv', delimiter=';')
#white_df = pd.read_csv('C:/Users/Eugene/Documents/GitHub/BoyWithLuv-Team/Wine_Quality/wine_data/winequality-white.csv', delimiter=';')
red_df = pd.read_csv("C:\\Users\\Republic Of Gamers\\OneDrive - Asia Pacific University\\wine+quality\\winequality-red.csv", delimiter = ';')
white_df = pd.read_csv("C:\\Users\\Republic Of Gamers\\OneDrive - Asia Pacific University\\wine+quality\\winequality-white.csv", delimiter = ';')

# %%
red_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
columns_to_plot = ['alcohol', 'fixed acidity', 'volatile acidity', 'citric acid', 
                   'residual sugar', 'chlorides', 'free sulfur dioxide', 
                   'total sulfur dioxide', 'density', 'pH', 'sulphates']

# Add empty slots to fill the 12 subplots
columns_to_plot += [None] * (12 - len(columns_to_plot))

# Create subplots
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(18, 12))

# Plot each column's distribution
for i, column in enumerate(columns_to_plot):
    row, col = divmod(i, 4)
    if column is not None and column in red_df.columns:
        sns.histplot(red_df[column], bins=30, kde=True, edgecolor='black', ax=axes[row, col], color='blue')  # Adjust color as needed
        axes[row, col].set_title(f'Overall Distribution of {column.capitalize()}')
        axes[row, col].set_xlabel(f'{column.capitalize()} Level')
        axes[row, col].set_ylabel('Count')
    else:
        axes[row, col].axis('off')
        axes[row, col].set_title(f'No Data for {column.capitalize() if column else "Empty"}')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fig = sns.FacetGrid(red_df, col='quality', col_wrap=3, height=4)

# Map the histogram plot to each facet
fig.map(sns.histplot, 'alcohol', bins=30, kde=True, edgecolor='black')

# Add titles and labels
fig.set_titles(col_template='Quality {col_name}')
fig.set_axis_labels('Alcohol Content (%)', 'Count')

plt.show()
# Out:
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
quality_3_data = red_df[red_df['quality'] == 3]

columns_to_plot = ['alcohol', 'fixed acidity', 'volatile acidity', 'citric acid', 
                   'residual sugar', 'chlorides', 'free sulfur dioxide', 
                   'total sulfur dioxide', 'density', 'pH', 'sulphates']

columns_to_plot += [None] * (12 - len(columns_to_plot))

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(18, 12))

for i, column in enumerate(columns_to_plot):
    row, col = divmod(i, 4)
    if column is not None and column in quality_3_data.columns:
        sns.histplot(quality_3_data[column], bins=30, kde=True, edgecolor='black', ax=axes[row, col], color=colors[i])
        axes[row, col].set_title(f'{column.capitalize()} for Quality 3')
        axes[row, col].set_xlabel(f'{column.capitalize()} Level')
        axes[row, col].set_ylabel('Count')
    else:
        axes[row, col].axis('off')
        axes[row, col].set_title(f'No Data for {column.capitalize() if column else "Empty"}')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
quality_4_data = red_df[red_df['quality'] == 4]

columns_to_plot = ['alcohol', 'fixed acidity', 'volatile acidity', 'citric acid', 
                   'residual sugar', 'chlorides', 'free sulfur dioxide', 
                   'total sulfur dioxide', 'density', 'pH', 'sulphates']

columns_to_plot += [None] * (12 - len(columns_to_plot))

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(18, 12))

for i, column in enumerate(columns_to_plot):
    row, col = divmod(i, 4)
    if column is not None and column in quality_4_data.columns:
        sns.histplot(quality_3_data[column], bins=30, kde=True, edgecolor='black', ax=axes[row, col], color=colors[i])
        axes[row, col].set_title(f'{column.capitalize()} for Quality 3')
        axes[row, col].set_xlabel(f'{column.capitalize()} Level')
        axes[row, col].set_ylabel('Count')
    else:
        axes[row, col].axis('off')
        axes[row, col].set_title(f'No Data for {column.capitalize() if column else "Empty"}')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the data for quality 3
quality_3_data = red_df[red_df['quality'] == 3]

# Melt the DataFrame to long format for FacetGrid
melted_data = quality_3_data.melt(value_vars=['alcohol', 'fixed acidity', 'volatile acidity', 
                                                'citric acid', 'residual sugar', 'chlorides', 
                                                'free sulfur dioxide', 'total sulfur dioxide', 
                                                'density', 'pH', 'sulphates'], 
                                    var_name='Variable', value_name='Value')

# Create a FacetGrid to show histograms for each variable
g = sns.FacetGrid(melted_data, col='Variable', col_wrap=3, height=4)
g.map(sns.histplot, 'Value', bins=30, kde=True, edgecolor='black')

# Add titles and labels
g.set_titles(col_template='{col_name}')
g.set_axis_labels('Value', 'Count')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fig = sns.FacetGrid(red_df, col='quality', col_wrap=3, height=4)

# Map the histogram plot to each facet
fig.map(sns.histplot, 'fixed acidity', bins=30, kde=True, edgecolor='black')

# Add titles and labels
fig.set_titles(col_template='Quality {col_name}')
fig.set_axis_labels('Acidity', 'Count')

plt.show()
# Out:
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Republic Of Gamers\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
white_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...
